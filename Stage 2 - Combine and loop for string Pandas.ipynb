# %%
import pandas as pd

# %%
df1 = pd.read_csv("knowyourname.csv")

# %%
df2 = pd.read_csv("knowhername.csv")

# %%
full=df1.append(df2)

# %%
full
# Out:
#     Unnamed: 0               artist                 song  \
# 0          319           Air Supply      One Step Closer
# 1          321           Air Supply    Peaches And Cream
# 2          654              America              Foolin'
# 3          770                Annie            Heartbeat
# 4         2023    Bruce Springsteen    Darlington County
# ..         ...                  ...                  ...
# 31       52400  Stone Temple Pilots    Lady Picture Show
# 32       53031           Thin Lizzy          Cowboy Song
# 33       53056           Thin Lizzy  Killer On The Loose
# 34       56923               Xscape        The Runaround
# 35       57500          Young Jeezy         Way Too Gone
#
#                                                  link  \
# 0         /a/air+supply/one+step+closer_20004939.html
# 1       /a/air+supply/peaches+and+cream_20289707.html
# 2                     /a/america/foolin_20007240.html
# 3                    /a/annie/heartbeat_20219478.html
# ...

# %%
full["Opinion"] = pd.Series().astype('object')

# %%
full
# Out:
#     Unnamed: 0               artist                 song  \
# 0          319           Air Supply      One Step Closer
# 1          321           Air Supply    Peaches And Cream
# 2          654              America              Foolin'
# 3          770                Annie            Heartbeat
# 4         2023    Bruce Springsteen    Darlington County
# ..         ...                  ...                  ...
# 31       52400  Stone Temple Pilots    Lady Picture Show
# 32       53031           Thin Lizzy          Cowboy Song
# 33       53056           Thin Lizzy  Killer On The Loose
# 34       56923               Xscape        The Runaround
# 35       57500          Young Jeezy         Way Too Gone
#
#                                                  link  \
# 0         /a/air+supply/one+step+closer_20004939.html
# 1       /a/air+supply/peaches+and+cream_20289707.html
# 2                     /a/america/foolin_20007240.html
# 3                    /a/annie/heartbeat_20219478.html
# ...

# %% [markdown]
# #def standpointification(df):
#  #   for text in df['text']:
#   #      if 'i wanna know your name' in text.lower() or 'want to know your name' in text.lower():
#    #         df['Opinion'] = 'Wants to know name'
#     #    elif  df['Opinion'] = "Doesn't want to know name"

# %%
#def standpointification(df):
 #   for index, row in df.iterrows():
  #      value = df.loc[df.isin(['sleepin']).any(axis=1)].index.tolist()
   # if value:
    #    df.at[index, 'Opinion'] = 'Wants to know name'  
    #else:
     #   df.at[index, 'Opinion'] = "Doesn't want to know name"

# %%
opinionnotification(full)
# Out:
#     Unnamed: 0               artist                 song  \
# 0          319           Air Supply      One Step Closer
# 1          321           Air Supply    Peaches And Cream
# 2          654              America              Foolin'
# 3          770                Annie            Heartbeat
# 4         2023    Bruce Springsteen    Darlington County
# ..         ...                  ...                  ...
# 31       52400  Stone Temple Pilots    Lady Picture Show
# 32       53031           Thin Lizzy          Cowboy Song
# 33       53056           Thin Lizzy  Killer On The Loose
# 34       56923               Xscape        The Runaround
# 35       57500          Young Jeezy         Way Too Gone
#
#                                                  link  \
# 0         /a/air+supply/one+step+closer_20004939.html
# 1       /a/air+supply/peaches+and+cream_20289707.html
# 2                     /a/america/foolin_20007240.html
# 3                    /a/annie/heartbeat_20219478.html
# ...

# %%
full
# Out:
#     Unnamed: 0               artist                 song  \
# 0          319           Air Supply      One Step Closer
# 1          321           Air Supply    Peaches And Cream
# 2          654              America              Foolin'
# 3          770                Annie            Heartbeat
# 4         2023    Bruce Springsteen    Darlington County
# ..         ...                  ...                  ...
# 31       52400  Stone Temple Pilots    Lady Picture Show
# 32       53031           Thin Lizzy          Cowboy Song
# 33       53056           Thin Lizzy  Killer On The Loose
# 34       56923               Xscape        The Runaround
# 35       57500          Young Jeezy         Way Too Gone
#
#                                                  link  \
# 0         /a/air+supply/one+step+closer_20004939.html
# 1       /a/air+supply/peaches+and+cream_20289707.html
# 2                     /a/america/foolin_20007240.html
# 3                    /a/annie/heartbeat_20219478.html
# ...

# %%
#while len(opinionslist) < 149:
#    opinionslist.append("Don't know")

# %% [markdown]
# print(opinionslist)

# %%
#len(opinionslist)
# Out:
# 149

# %%
# Out:
#     Unnamed: 0               artist                 song  \
# 0          319           Air Supply      One Step Closer
# 1          321           Air Supply    Peaches And Cream
# 2          654              America              Foolin'
# 3          770                Annie            Heartbeat
# 4         2023    Bruce Springsteen    Darlington County
# ..         ...                  ...                  ...
# 31       52400  Stone Temple Pilots    Lady Picture Show
# 32       53031           Thin Lizzy          Cowboy Song
# 33       53056           Thin Lizzy  Killer On The Loose
# 34       56923               Xscape        The Runaround
# 35       57500          Young Jeezy         Way Too Gone
#
#                                                  link  \
# 0         /a/air+supply/one+step+closer_20004939.html
# 1       /a/air+supply/peaches+and+cream_20289707.html
# 2                     /a/america/foolin_20007240.html
# 3                    /a/annie/heartbeat_20219478.html
# ...

# %%
#For every row 
#finder = list.find("know your name")
#print(finder[-10:])
#Find know your name and print out know your name +

# %%
opinionnotification(full)
# Out:
#     Unnamed: 0               artist                 song  \
# 0          319           Air Supply      One Step Closer
# 1          321           Air Supply    Peaches And Cream
# 2          654              America              Foolin'
# 3          770                Annie            Heartbeat
# 4         2023    Bruce Springsteen    Darlington County
# ..         ...                  ...                  ...
# 31       52400  Stone Temple Pilots    Lady Picture Show
# 32       53031           Thin Lizzy          Cowboy Song
# 33       53056           Thin Lizzy  Killer On The Loose
# 34       56923               Xscape        The Runaround
# 35       57500          Young Jeezy         Way Too Gone
#
#                                                  link  \
# 0         /a/air+supply/one+step+closer_20004939.html
# 1       /a/air+supply/peaches+and+cream_20289707.html
# 2                     /a/america/foolin_20007240.html
# 3                    /a/annie/heartbeat_20219478.html
# ...

# %%
def opinionnotification(df):
    for index, row in df.iterrows():
        if 'i wanna know your name' in row['text'].lower():
            df.at[index, 'Opinion'] = 'Wants to know name'
        elif 'i want to know your name' in row['text'].lower():
            df.at[index, 'Opinion'] = 'Wants to know name'
        elif 'i wanna know her name' in row['text'].lower():
            df.at[index, 'Opinion'] = 'Wants to know name'
        elif 'i want to know her name' in row['text'].lower():
            df.at[index, 'Opinion'] = 'Wants to know name'
        elif 'just want to know your name' in row['text'].lower():
            df.at[index, 'Opinion'] = 'Wants to know name'
        elif 'just wanna know your name' in row['text'].lower():
            df.at[index, 'Opinion'] = 'Wants to know name'
        elif 'wanted to know your name' in row['text'].lower():
            df.at[index, 'Opinion'] = 'Wants to know name'
        elif 'wanted to know her name' in row['text'].lower():
            df.at[index, 'Opinion'] = 'Wants to know name'
        elif "don't want to know your name" in row['text'].lower():
            df.at[index, 'Opinion'] = "Doesn't want to know name"
        elif "don't wanna know your name" in row['text'].lower():
            df.at[index, 'Opinion'] = "Doesn't want to know name"
        elif "don't know your name" in row['text'].lower():
            df.at[index, 'Opinion'] = "Reasonably concerned"    
        elif "did not know your name" in row['text'].lower():
            df.at[index, 'Opinion'] = "Reasonably concerned"
        else:
            df.at[index, 'Opinion'] = "Unknown"
    return df

# %%
full.to_csv('full.csv', index=False)
